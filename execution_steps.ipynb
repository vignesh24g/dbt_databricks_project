# %%
# %pip install dbt-databricks

# %%
# !ls

# %%
# !dbt debug

# %%
# !dbt run --select example

# %%
# %sql
select * from default.example

# %%
# !dbt list

# %%
# !dbt parse

# %%
# !dbt clean

# %%
# !dbt test --select example

# %%
# !dbt docs generate --select example
